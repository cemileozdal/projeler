# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
DATA_DIR = '/content/gdrive/MyDrive/yolov8/beyin/files'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 kB 8.9 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8l-cls.pt')

results = model.train(data=DATA_DIR, epochs=25, imgsz=64)
# Out:
# ...
# 100%|██████████| 71.7M/71.7M [00:00<00:00, 218MB/s]
# Ultralytics YOLOv8.0.206 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/MyDrive/yolov8/beyin/files/test/tumor/1.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/yolov8/beyin/files/test/tumor/1.jpg: 64x64 tumor 1.00, aneurysm 0.00, cancer 0.00, 48.4ms
# Speed: 0.5ms preprocess, 48.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
