# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
DATA_DIR = '/content/gdrive/MyDrive/yolov8/CİĞER/files'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 9.0 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8l-cls.pt')

results = model.train(data=DATA_DIR, epochs=25, imgsz=64)
# Out:
# ...
# 100%|██████████| 71.7M/71.7M [00:00<00:00, 225MB/s]
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/MyDrive/yolov8/CİĞER/files/train/atherosclerosis_of_the_aorta/0.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/yolov8/CİĞER/files/train/atherosclerosis_of_the_aorta/0.jpg: 64x64 atherosclerosis_of_the_aorta 1.00, hydrothorax 0.00, cardiomegaly 0.00, post_traumatic_ribs_deformation 0.00, atelectasis 0.00, 14.5ms
# Speed: 0.8ms preprocess, 14.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
